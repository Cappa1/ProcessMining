# %% [markdown]
# ## Preprocessing & pipelines

# %% [markdown]
# ### Imports

# %% [markdown]
# Here we import the data, and do the basic initial transformations like creating the unix time column

# %%
import numpy as np
import pandas as pd
import os
import psutil

np.random.seed(42)

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
plt.rcParams["figure.figsize"] = [16, 11]
plt.rcParams["figure.autolayout"] = True

import time
import datetime
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
# helper functions

def data_split(df):
    """returns 10% of the data"""
    return df[: int((len(df)/10))]


def EventTime(data):
    """function to add the time of the event"""
    for i in list(data["case concept:name"].unique()):
        data.loc[data["case concept:name"] == i, "nextTIME"] = data.loc[data["case concept:name"] == i, 
                                                                "event time:timestamp"].shift(-1)
    return data

def PrevEventTime(data):
    """function to add the time of the event"""
    for i in list(data["case concept:name"].unique()):
        data.loc[data["case concept:name"] == i, "prevTIME"] = data.loc[data["case concept:name"] == i, 
                                                                "event time:timestamp"].shift(1)
    return data

def next_event(data, lst, case, nxt, name):
    """function to add the next event of a trace"""
    for i in lst:
        data.loc[data[case] == i, nxt] = data.loc[data[case] == i, name].shift(-1)
    return data

def prev_event(data, lst, case, nxt, name):
    """function to add the next event of a trace"""
    for i in lst:
        data.loc[data[case] == i, nxt] = data.loc[data[case] == i, name].shift(1)
    return data

def UnixTime(df, col="timestamp", newcol="Unix"):
    """Adds a new column to the dataframe containing the UNIX time of the timestamp"""
    cop = df.copy()
    cop[col] = pd.to_datetime(cop[col], dayfirst=True)
    unixTransform = lambda x: time.mktime(x.timetuple())
    df[newcol] = cop[col].apply(unixTransform)

# %%
path = r"D:/University/Year 2/Q3/DBL/Data/"
train = pd.read_csv(f'{path}BPI Challenge 2017/BPI_Challenge_2017-training.csv')
test = pd.read_csv(f'{path}BPI Challenge 2017/BPI_Challenge_2017-test.csv')


data = pd.concat([train, test])

# %%
# strip whitespace of column names and add extra time columns
data.columns = data.columns.str.strip()
data["timestamp"] = data["event time:timestamp"].copy()
data["event time:timestamp"] = pd.to_datetime(data["event time:timestamp"], dayfirst=True)
data['time of day'] = data["timestamp"].str.split(expand=True)[1]

# %%
data["weekday"] = data["event time:timestamp"].dt.day_name()

# %%
UnixTime(data)

# %%
data.sort_values(by=['Unix'], inplace=True)
data.head()
# Out:
#    eventID           case LoanGoal case ApplicationType  \
# 0        0  Existing loan takeover           New credit
# 1        1  Existing loan takeover           New credit
# 2        2  Existing loan takeover           New credit
# 3        3  Existing loan takeover           New credit
# 4        4  Existing loan takeover           New credit
#
#        case concept:name  case RequestedAmount event Action  \
# 0  Application_652823628             20000.000      Created
# 1  Application_652823628             20000.000  statechange
# 2  Application_652823628             20000.000      Created
# 3  Application_652823628             20000.000      Deleted
# 4  Application_652823628             20000.000      Created
#
#   event org:resource      event concept:name event EventOrigin  \
# 0             User_1    A_Create Application       Application
# 1             User_1             A_Submitted       Application
# 2             User_1          W_Handle leads          Workflow
# 3             User_1          W_Handle leads          Workflow
# 4             User_1  W_Complete application          Workflow
#
#            event EventID event lifecycle:transition    event time:timestamp  \
# 0  Application_652823628                   complete 2016-01-01 10:51:15.304
# 1   ApplState_1582051990                   complete 2016-01-01 10:51:15.352
# 2    Workitem_1298499574                   schedule 2016-01-01 10:51:15.774
# 3    Workitem_1673366067                   withdraw 2016-01-01 10:52:36.392
# 4    Workitem_1493664571                   schedule 2016-01-01 10:52:36.403
#
#                  timestamp   time of day weekday           Unix
# 0  01-01-2016 10:51:15.304  10:51:15.304  Friday 1451641875.000
# 1  01-01-2016 10:51:15.352  10:51:15.352  Friday 1451641875.000
# 2  01-01-2016 10:51:15.774  10:51:15.774  Friday 1451641875.000
# 3  01-01-2016 10:52:36.392  10:52:36.392  Friday 1451641956.000
# 4  01-01-2016 10:52:36.403  10:52:36.403  Friday 1451641956.000

# %%
# test = data[: 100].copy()

# %%
# drop useless columns
def dropper(df, lbls=["eventID", "event EventID", "timestamp"]):
    df.drop(labels=lbls, axis=1, inplace=True)

dropper(data)

# %%
data
# Out:
#                  case LoanGoal case ApplicationType      case concept:name  \
# 0       Existing loan takeover           New credit  Application_652823628
# 1       Existing loan takeover           New credit  Application_652823628
# 2       Existing loan takeover           New credit  Application_652823628
# 3       Existing loan takeover           New credit  Application_652823628
# 4       Existing loan takeover           New credit  Application_652823628
# ...                        ...                  ...                    ...
# 241054  Existing loan takeover           New credit  Application_637536789
# 241055  Existing loan takeover           New credit  Application_637536789
# 241056  Other, see explanation           New credit   Application_16193774
# 241057  Existing loan takeover           New credit  Application_586083090
# 241058  Existing loan takeover           New credit  Application_586083090
#
#         case RequestedAmount event Action event org:resource  \
# 0                  20000.000      Created             User_1
# 1                  20000.000  statechange             User_1
# 2                  20000.000      Created             User_1
# 3                  20000.000      Deleted             User_1
# 4                  20000.000      Created             User_1
# ...                      ...          ...                ...
# 241054             17250.000  statechange           User_131
# 241055             17250.000     Released           User_131
# 241056             45000.000     Released            User_56
# 241057             50000.000     Obtained           User_100
# 241058             50000.000     Released           User_100
#
#              event concept:name event EventOrigin event lifecycle:transition  \
# 0          A_Create Application       Application                   complete
# 1                   A_Submitted       Application                   complete
# 2                W_Handle leads          Workflow                   schedule
# 3                W_Handle leads          Workflow                   withdraw
# 4        W_Complete application          Workflow                   schedule
# ...                         ...               ...                        ...
# 241054             A_Validating       Application                   complete
# 241055   W_Validate application          Workflow                    suspend
# 241056  W_Call incomplete files          Workflow                    suspend
# 241057   W_Validate application          Workflow                     resume
# 241058   W_Validate application          Workflow                    suspend
#
#           event time:timestamp   time of day    weekday           Unix
# 0      2016-01-01 10:51:15.304  10:51:15.304     Friday 1451641875.000
# 1      2016-01-01 10:51:15.352  10:51:15.352     Friday 1451641875.000
# 2      2016-01-01 10:51:15.774  10:51:15.774     Friday 1451641875.000
# 3      2016-01-01 10:52:36.392  10:52:36.392     Friday 1451641956.000
# 4      2016-01-01 10:52:36.403  10:52:36.403     Friday 1451641956.000
# ...                        ...           ...        ...            ...
# 241054 2017-02-01 15:00:30.347  15:00:30.347  Wednesday 1485957630.000
# 241055 2017-02-01 15:01:24.191  15:01:24.191  Wednesday 1485957684.000
# 241056 2017-02-01 15:09:03.331  15:09:03.331  Wednesday 1485958143.000
# 241057 2017-02-01 15:10:52.793  15:10:52.793  Wednesday 1485958252.000
# 241058 2017-02-01 15:11:03.499  15:11:03.499  Wednesday 1485958263.000
#
# [1202267 rows x 13 columns]

# %%
data["Unix"] = data["Unix"].astype(int)

# %% [markdown]
# ### Event/time adder

# %%
# assign long column names to variables for easier use
cases = "case concept:name"
reg_date = "case REG_DATE"
amount_req = "case AMOUNT_REQ"
event_name = "event concept:name"
lifecycle = "event lifecycle:transition"
tmstmp = "event time:timestamp"
nxt_event = "next event"
dtime = "delta time"

# %%
# event shifting
data[nxt_event] = data.groupby('case concept:name')['event concept:name'].shift(-1)
data["prev event"] = data.groupby('case concept:name')['event concept:name'].shift(1)

# %%
# time shifting
data["nextUnix"] = data.groupby('case concept:name')['Unix'].shift(-1)
data["prevUnix"] = data.groupby('case concept:name')['Unix'].shift(1)
data["nextTime"] = data.groupby('case concept:name')['event time:timestamp'].shift(-1)
data["prevTime"] = data.groupby('case concept:name')['event time:timestamp'].shift(1)

# %%
len(data[data["prevTime"].isna()])/len(data)
# Out:
# 0.026207988741269617

# %%
len(data[data["prevTime"].isna()])
# Out:
# 31509

# %%
len(data)
# Out:
# 1202267

# %%
import math

# Adding time features
data['day'] = data['event time:timestamp'].dt.day;
data['month'] = data['event time:timestamp'].dt.month;
data['hour'] = data['event time:timestamp'].dt.hour;
data['day_of_week'] = data['event time:timestamp'].dt.weekday;

# Cyclical encoding
data["hour"] = 2 * math.pi * data["hour"] / data["hour"].max()
data["hour_cos"] = np.cos(data["hour"])
data["hour_sin"] = np.sin(data["hour"])
data["day_of_week"] = 2 * math.pi * data["day_of_week"] / data["day_of_week"].max()
data["day_of_week_cos"] = np.cos(data["day_of_week"])
data["day_of_week_sin"] = np.sin(data["day_of_week"])

# %%
data['day_of_week'].unique()
# Out:
# array([4.1887902 , 5.23598776, 6.28318531, 0.        , 1.04719755,
#        2.0943951 , 3.14159265])

# %%
data
# Out:
#                  case LoanGoal case ApplicationType      case concept:name  \
# 0       Existing loan takeover           New credit  Application_652823628
# 1       Existing loan takeover           New credit  Application_652823628
# 2       Existing loan takeover           New credit  Application_652823628
# 3       Existing loan takeover           New credit  Application_652823628
# 4       Existing loan takeover           New credit  Application_652823628
# ...                        ...                  ...                    ...
# 241054  Existing loan takeover           New credit  Application_637536789
# 241055  Existing loan takeover           New credit  Application_637536789
# 241056  Other, see explanation           New credit   Application_16193774
# 241057  Existing loan takeover           New credit  Application_586083090
# 241058  Existing loan takeover           New credit  Application_586083090
#
#         case RequestedAmount event Action event org:resource  \
# 0                  20000.000      Created             User_1
# 1                  20000.000  statechange             User_1
# 2                  20000.000      Created             User_1
# 3                  20000.000      Deleted             User_1
# 4                  20000.000      Created             User_1
# ...                      ...          ...                ...
# 241054             17250.000  statechange           User_131
# 241055             17250.000     Released           User_131
# 241056             45000.000     Released            User_56
# 241057             50000.000     Obtained           User_100
# 241058             50000.000     Released           User_100
#
#              event concept:name event EventOrigin event lifecycle:transition  \
# 0          A_Create Application       Application                   complete
# 1                   A_Submitted       Application                   complete
# 2                W_Handle leads          Workflow                   schedule
# 3                W_Handle leads          Workflow                   withdraw
# 4        W_Complete application          Workflow                   schedule
# ...                         ...               ...                        ...
# 241054             A_Validating       Application                   complete
# 241055   W_Validate application          Workflow                    suspend
# 241056  W_Call incomplete files          Workflow                    suspend
# 241057   W_Validate application          Workflow                     resume
# 241058   W_Validate application          Workflow                    suspend
#
#           event time:timestamp  ...                nextTime  \
# 0      2016-01-01 10:51:15.304  ... 2016-01-01 10:51:15.352
# 1      2016-01-01 10:51:15.352  ... 2016-01-01 10:51:15.774
# 2      2016-01-01 10:51:15.774  ... 2016-01-01 10:52:36.392
# 3      2016-01-01 10:52:36.392  ... 2016-01-01 10:52:36.403
# 4      2016-01-01 10:52:36.403  ... 2016-01-01 10:52:36.413
# ...                        ...  ...                     ...
# 241054 2017-02-01 15:00:30.347  ... 2017-02-01 15:01:24.191
# 241055 2017-02-01 15:01:24.191  ...                     NaT
# 241056 2017-02-01 15:09:03.331  ...                     NaT
# 241057 2017-02-01 15:10:52.793  ... 2017-02-01 15:11:03.499
# 241058 2017-02-01 15:11:03.499  ...                     NaT
#
#                       prevTime  day month  hour  day_of_week  hour_cos  \
# 0                          NaT    1     1 2.732        4.189    -0.917
# 1      2016-01-01 10:51:15.304    1     1 2.732        4.189    -0.917
# 2      2016-01-01 10:51:15.352    1     1 2.732        4.189    -0.917
# 3      2016-01-01 10:51:15.774    1     1 2.732        4.189    -0.917
# 4      2016-01-01 10:52:36.392    1     1 2.732        4.189    -0.917
# ...                        ...  ...   ...   ...          ...       ...
# 241054 2017-02-01 15:00:30.275    1     2 4.098        2.094    -0.577
# 241055 2017-02-01 15:00:30.347    1     2 4.098        2.094    -0.577
# 241056 2017-02-01 14:50:56.564    1     2 4.098        2.094    -0.577
# 241057 2017-02-01 14:54:03.544    1     2 4.098        2.094    -0.577
# 241058 2017-02-01 15:10:52.793    1     2 4.098        2.094    -0.577
#
#        hour_sin day_of_week_cos  day_of_week_sin
# 0         0.398          -0.500           -0.866
# 1         0.398          -0.500           -0.866
# 2         0.398          -0.500           -0.866
# 3         0.398          -0.500           -0.866
# 4         0.398          -0.500           -0.866
# ...         ...             ...              ...
# 241054   -0.817          -0.500            0.866
# 241055   -0.817          -0.500            0.866
# 241056   -0.817          -0.500            0.866
# 241057   -0.817          -0.500            0.866
# 241058   -0.817          -0.500            0.866
#
# [1202267 rows x 27 columns]

# %%
# lst_events = data[cases].unique().tolist()
# next_event(data, lst_events, cases, nxt_event, event_name);
# EventTime(data);

# %%
data.to_pickle("processed2017.pkl")

# %%
# data["timestamp"] = data["event time:timestamp"].copy()
# data['time of day'] = data["timestamp"].str.split(expand=True)[1]
# data["event time:timestamp"] = pd.to_datetime(data["event time:timestamp"], dayfirst=True)

# %%
test = data[: 100]
test
# Out:
#              case LoanGoal case ApplicationType       case concept:name  \
# 0   Existing loan takeover           New credit   Application_652823628
# 1   Existing loan takeover           New credit   Application_652823628
# 2   Existing loan takeover           New credit   Application_652823628
# 3   Existing loan takeover           New credit   Application_652823628
# 4   Existing loan takeover           New credit   Application_652823628
# ..                     ...                  ...                     ...
# 95                     Car           New credit  Application_1806387393
# 97           Not speficied           New credit  Application_1111870538
# 98           Not speficied           New credit  Application_1111870538
# 96           Not speficied           New credit  Application_1111870538
# 99           Not speficied           New credit  Application_1111870538
#
#     case RequestedAmount event Action event org:resource  \
# 0              20000.000      Created             User_1
# 1              20000.000  statechange             User_1
# 2              20000.000      Created             User_1
# 3              20000.000      Deleted             User_1
# 4              20000.000      Created             User_1
# ..                   ...          ...                ...
# 95              5000.000      Created             User_1
# 97              5000.000  statechange             User_1
# 98              5000.000      Created             User_1
# 96              5000.000      Created             User_1
# 99              5000.000      Deleted             User_1
#
#         event concept:name event EventOrigin event lifecycle:transition  \
# 0     A_Create Application       Application                   complete
# 1              A_Submitted       Application                   complete
# 2           W_Handle leads          Workflow                   schedule
# 3           W_Handle leads          Workflow                   withdraw
# 4   W_Complete application          Workflow                   schedule
# ..                     ...               ...                        ...
# 95          W_Handle leads          Workflow                   schedule
# 97             A_Submitted       Application                   complete
# 98          W_Handle leads          Workflow                   schedule
# 96    A_Create Application       Application                   complete
# 99          W_Handle leads          Workflow                   withdraw
#
#       event time:timestamp  ...                nextTime  \
# 0  2016-01-01 10:51:15.304  ... 2016-01-01 10:51:15.352
# 1  2016-01-01 10:51:15.352  ... 2016-01-01 10:51:15.774
# 2  2016-01-01 10:51:15.774  ... 2016-01-01 10:52:36.392
# 3  2016-01-01 10:52:36.392  ... 2016-01-01 10:52:36.403
# 4  2016-01-01 10:52:36.403  ... 2016-01-01 10:52:36.413
# ..                     ...  ...                     ...
# 95 2016-01-01 18:58:26.524  ... 2016-01-02 10:38:15.267
# 97 2016-01-01 20:13:17.442  ... 2016-01-01 20:13:17.750
# 98 2016-01-01 20:13:17.750  ... 2016-01-01 20:13:17.386
# 96 2016-01-01 20:13:17.386  ... 2016-01-01 20:13:53.205
# 99 2016-01-01 20:13:53.205  ... 2016-01-01 20:13:53.215
#
#                   prevTime  day month  hour  day_of_week  hour_cos hour_sin  \
# 0                      NaT    1     1 2.732        4.189    -0.917    0.398
# 1  2016-01-01 10:51:15.304    1     1 2.732        4.189    -0.917    0.398
# 2  2016-01-01 10:51:15.352    1     1 2.732        4.189    -0.917    0.398
# 3  2016-01-01 10:51:15.774    1     1 2.732        4.189    -0.917    0.398
# 4  2016-01-01 10:52:36.392    1     1 2.732        4.189    -0.917    0.398
# ..                     ...  ...   ...   ...          ...       ...      ...
# 95 2016-01-01 18:58:26.216    1     1 4.917        4.189     0.203   -0.979
# 97                     NaT    1     1 5.464        4.189     0.683   -0.731
# 98 2016-01-01 20:13:17.442    1     1 5.464        4.189     0.683   -0.731
# 96 2016-01-01 20:13:17.750    1     1 5.464        4.189     0.683   -0.731
# 99 2016-01-01 20:13:17.386    1     1 5.464        4.189     0.683   -0.731
#
#    day_of_week_cos  day_of_week_sin
# 0           -0.500           -0.866
# 1           -0.500           -0.866
# 2           -0.500           -0.866
# 3           -0.500           -0.866
# 4           -0.500           -0.866
# ..             ...              ...
# 95          -0.500           -0.866
# 97          -0.500           -0.866
# 98          -0.500           -0.866
# 96          -0.500           -0.866
# 99          -0.500           -0.866
#
# [100 rows x 27 columns]

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class Tester(BaseEstimator, TransformerMixin):

    def __init__(self):
        self.

    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
# Out:
#   File "C:\Users\Jarl\AppData\Local\Temp/ipykernel_7732/2623523266.py", line 8
#     def fit(self, X, y=None):
#     ^
# IndentationError: expected an indented block
