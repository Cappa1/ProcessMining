# %%
import warnings
warnings.filterwarnings('ignore')
# DEMO = True

# %%
# %run config.ipynb
# %run preprocessing.ipynb
# %run NaiveBaseline.ipynb
# %run DecisionTree.ipynb
# %run FirstLinModel.ipynb
# %run RandomForest.ipynb
# %run final_preprocess.ipynb
# Out:
# Wall time: 16.5 s

# %%
import time
import psutil
import numpy as np
import pandas as pd
import warnings
import random
warnings.filterwarnings('ignore')

np.random.seed(42)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
test_data = get_data(TRAIN, TEST)

# test_data = preprocess(test_data)

# X_train, X_test, y_train, y_test = features_split(test_data)

# samx, samy = sampler(X_train, y_train)

# %%
#UPDATE
# %run preprocessing.ipynb
# %run RandomForest.ipynb

# %%
time_process()

# %%
test_data.shape
# Out:
# (1202267, 12)

# %%
# %%time
unixTransform = lambda x: time.mktime(x.timetuple())
test_data["event time:timestamp"] = pd.to_datetime(test_data["event time:timestamp"], dayfirst=True)
test_data["UNIX"] = test_data["event time:timestamp"].apply(unixTransform)
# Out:
# Wall time: 2min 1s

# %%
sum(test_data.groupby("case concept:name")["UNIX"].diff().dropna() < 0)
# Out:
# 0

# %%
new_test_data = test_data.sort_values(by=["event time:timestamp"])

# %%
new_test_data[new_test_data["case concept:name"] == "Application_424064154"]["event time:timestamp"]
# Out:
# 0       2016-10-19 01:42:39.265
# 1       2016-10-19 01:42:40.100
# 2       2016-10-19 01:42:40.711
# 15      2016-10-19 07:54:43.412
# 22      2016-10-19 07:56:36.333
# 23      2016-10-19 07:56:36.338
# 24      2016-10-19 07:56:36.340
# 25      2016-10-19 07:56:36.342
# 26      2016-10-19 07:56:39.078
# 1805    2016-10-20 16:51:24.848
# 1806    2016-10-20 16:52:01.541
# 1833    2016-10-20 17:05:05.944
# 1850    2016-10-20 17:16:14.691
# 1854    2016-10-20 17:24:48.766
# 1855    2016-10-20 17:24:49.364
# 1864    2016-10-20 17:26:24.764
# 1865    2016-10-20 17:26:24.778
# 1866    2016-10-20 17:26:24.784
# 1867    2016-10-20 17:26:24.786
# 1868    2016-10-20 17:26:24.788
# 1876    2016-10-20 17:33:00.679
# 6849    2016-10-24 15:33:51.593
# 6850    2016-10-24 15:34:14.961
# 84212   2016-11-20 08:00:37.116
# 84213   2016-11-20 08:00:37.141
# 84214   2016-11-20 08:00:37.152
# Name: event time:timestamp, dtype: datetime64[ns]

# %%
test_data[test_data["case concept:name"] == "Application_424064154"]["event time:timestamp"]
# Out:
# 0       2016-10-19 01:42:39.265
# 1       2016-10-19 01:42:40.100
# 2       2016-10-19 01:42:40.711
# 15      2016-10-19 07:54:43.412
# 22      2016-10-19 07:56:36.333
# 23      2016-10-19 07:56:36.338
# 24      2016-10-19 07:56:36.340
# 25      2016-10-19 07:56:36.342
# 26      2016-10-19 07:56:39.078
# 1805    2016-10-20 16:51:24.848
# 1806    2016-10-20 16:52:01.541
# 1833    2016-10-20 17:05:05.944
# 1850    2016-10-20 17:16:14.691
# 1854    2016-10-20 17:24:48.766
# 1855    2016-10-20 17:24:49.364
# 1864    2016-10-20 17:26:24.764
# 1865    2016-10-20 17:26:24.778
# 1866    2016-10-20 17:26:24.784
# 1867    2016-10-20 17:26:24.786
# 1868    2016-10-20 17:26:24.788
# 1876    2016-10-20 17:33:00.679
# 6849    2016-10-24 15:33:51.593
# 6850    2016-10-24 15:34:14.961
# 84212   2016-11-20 08:00:37.116
# 84213   2016-11-20 08:00:37.141
# 84214   2016-11-20 08:00:37.152
# Name: event time:timestamp, dtype: datetime64[ns]

# %%
test_data[test_data["case concept:name"] == "Application_424064154"]["event time:timestamp"].values == new_test_data[new_test_data["case concept:name"] == "Application_424064154"]["event time:timestamp"]
# Out:
# 0        True
# 1        True
# 2        True
# 15       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 1805     True
# 1806     True
# 1833     True
# 1850     True
# 1854     True
# 1855     True
# 1864     True
# 1865     True
# 1866     True
# 1867     True
# 1868     True
# 1876     True
# 6849     True
# 6850     True
# 84212    True
# 84213    True
# 84214    True
# Name: event time:timestamp, dtype: bool

# %%
test_data[test_data["case concept:name"] == "Application_424064154"].values
# Out:
#               eventID           case LoanGoal case ApplicationType  \
# 0     108263240630272  Existing loan takeover           New credit
# 1     108263240630273  Existing loan takeover           New credit
# 2     108263240630274  Existing loan takeover           New credit
# 15    108263240630275  Existing loan takeover           New credit
# 22    108263240630276  Existing loan takeover           New credit
# 23    108263240630277  Existing loan takeover           New credit
# 24    108263240630278  Existing loan takeover           New credit
# 25    108263240630279  Existing loan takeover           New credit
# 26    108263240630280  Existing loan takeover           New credit
# 1805  108263240630281  Existing loan takeover           New credit
#
#           case concept:name  case RequestedAmount event Action  \
# 0     Application_424064154             17250.000      Created
# 1     Application_424064154             17250.000  statechange
# ...

# %%
df_test = pd.read_csv(TEST)

# %%
df_test[df_test["eventID "].isin(new_test_data[new_test_data["event time:timestamp"].values != test_data["event time:timestamp"].values]["eventID"].values)]
# Out:
#                eventID            case LoanGoal case ApplicationType  \
# 0       108263240630272  Existing loan takeover           New credit
# 1       108263240630273  Existing loan takeover           New credit
# 2       108263240630274  Existing loan takeover           New credit
# 3       108267535597568  Other, see explanation           New credit
# 4       108267535597569  Other, see explanation           New credit
# ...                 ...                     ...                  ...
# 239820  131743826837541        Home improvement           New credit
# 239821  133049496895563                     Car           New credit
# 239822  133049496895564                     Car           New credit
# 239823  133049496895565                     Car           New credit
# 239824  131743826837542        Home improvement           New credit
#
#              case concept:name  case RequestedAmount event Action  \
# 0        Application_424064154             17250.000      Created
# ...

# %%
new_test_data[test_data["event time:timestamp"].values != new_test_data["event time:timestamp"]]["eventID"].values
# Out:
# array([108263240630272, 108263240630273, 108263240630274, ...,
#         91186450661486,  91186450661487,  91186450661488], dtype=int64)

# %%
test_data[test_data["case concept:name"] == "Application_424064154"]
# Out:
#                eventID           case LoanGoal case ApplicationType  \
# 0      108263240630272  Existing loan takeover           New credit
# 1      108263240630273  Existing loan takeover           New credit
# 2      108263240630274  Existing loan takeover           New credit
# 15     108263240630275  Existing loan takeover           New credit
# 22     108263240630276  Existing loan takeover           New credit
# 23     108263240630277  Existing loan takeover           New credit
# 24     108263240630278  Existing loan takeover           New credit
# 25     108263240630279  Existing loan takeover           New credit
# 26     108263240630280  Existing loan takeover           New credit
# 1805   108263240630281  Existing loan takeover           New credit
# 1806   108263240630282  Existing loan takeover           New credit
# 1833   108263240630283  Existing loan takeover           New credit
# 1850   108263240630284  Existing loan takeover           New credit
# ...

# %%
sum(new_test_data["event time:timestamp"].values != test_data["event time:timestamp"])
# Out:
# 270897

# %%
# %%time
preprocess_test_data = preprocess(get_data(TRAIN, TEST))
# Out:
# Converting datetime
# Conversion done
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-2ca71d0ad0db> in <module>
# ----> 1 preprocess_test_data = preprocess(get_data(TRAIN, TEST))
#
# <ipython-input-66-c88658d4d46e> in preprocess(data, labels, time)
#       6     """
#       7     if time:
# ----> 8         time_process(data, labels)
#       9     else:
#      10         pass
#
# <ipython-input-66-b9403f2627e1> in time_process(data, labels)
#       8     print("Conversion done")
#       9     data["UNIX"] = data["event time:timestamp"].apply(lambda x: time.mktime(x.timetuple()))
# ---> 10     remove_ms(data)
#      11 #     time_features(data, labels)
#      12 #     sort_time(data)
#
# <ipython-input-66-b9403f2627e1> in remove_ms(df)
#      30 def remove_ms(df):
#      31     """Removes milliseconds"""
# ...

# %%
test_data.shape
# Out:
# (1202267, 13)

# %%
preprocess_test_data["UNIX"] = preprocess_test_data["event time:timestamp"].apply(unixTransform)

# %%
sum(test_data["UNIX"].values != preprocess_test_data["UNIX"].values)
# Out:
# 270895

# %%
sum(preprocess_test_data.groupby("case concept:name")["UNIX"].diff().dropna() < 0)
# Out:
# 0

# %%
def run_all(train=TRAIN, test=TEST):
    """
    Executes the preprocessing and all models in the proper sequence
    param: TRAIN and TEST paths
    return: Print statements regarding running time and a csv containing the prediction results of the algorithms
    """

    start_time = time.time()

    # Start CPU load check
    cpu_process = psutil.Process()
    cpu_process.cpu_percent()

    # Fetch data
    print("Loading data..")
    data = get_data(train, test)
    forest_data = data.copy() # Create a copy for Final Random Forest
    print(f"Fetching the data took: {round(time.time() - start_time, 2)} seconds")
    print("\n")

    # Preprocessing
    prep_time = time.time()
    print("Preprocessing initiated..")
    processed = preprocess(data)
    print(f"Preprocessing took: {round(time.time() - prep_time, 2)} seconds")
    print("\n")
    
    # Naive Baseline:
    naive_time = time.time()
    time_time = time.time()
    print("Naive Baseline Initiated..")
    df_naive = processed.copy()
    print("Calculating time differences!")
    NaiveTime(df_naive)
    print(f"Time calculation done in: {round((time.time() - time_time), 2)} seconds")
    event_time = time.time()
    print("Predicting next events..")
    NaiveEvent(df_naive)
    print(f"Event prediction done in: {round(time.time() - event_time, 2)} seconds")
    print("\n")
    print(f"The baseline model ran in {round(time.time() - naive_time, 2)} seconds")
    print("\n")
    print("features split")
    X_train, X_test, y_train, y_test = features_split(processed)
    
    # Initial Linear Model
    lin_time = time.time()
    print("Initial Linear Model Running!")
    X_train_lin, X_test_lin, y_train_lin, y_test_lin = X_train.copy(), X_test.copy(), y_train.copy(), y_test.copy()
    SimpleModel(X_train_lin, X_test_lin, y_train_lin, y_test_lin)
    print(f"The inital linear model ran in: {round(time.time() - lin_time, 2)} seconds")
    print("\n")
    del X_train_lin, X_test_lin, y_train_lin, y_test_lin
    
    # Decision Tree
    tree_time = time.time()
    print("Decision Tree Initiated..")
    X_train_tree, X_test_tree, y_train_tree, y_test_tree = X_train.copy(), X_test.copy(), y_train.copy(), y_test.copy()
    TreeModel(X_train_tree, X_test_tree, y_train_tree, y_test_tree)
    print(f"The decision tree was constructed in: {round(time.time() - tree_time, 2)} seconds")
    print("\n")
    del X_train_tree, X_test_tree, y_train_tree, y_test_tree
    
    
    # Linear Model
    comp_time = time.time()
    print("Complex Linear Model Running..")
    
    #%run complexlinear.ipynb
    
    print(f"The complex linear model ran in: {round(time.time() - comp_time, 2)} seconds")
    print("\n")
    
    # PROCESSING THE DATA WITHOUT SORTING OR RUNNING OTHER TIME PROCESSING FUNCTIONS
    processed = preprocess(forest_data, ["event time:timestamp", "time of day", "weekday"], False)
    X_train, X_test, y_train, y_test = features_split(processed, False)
    # Random Forest
    forest_time = time.time()
    print("Random Forest growing..")
    
    # SET RANDOM SAMPLING FRAC, from 0-1
    
    X_forest, y_forest = sampler(X_train, y_train, 1)
    X_test_forest, y_test_forest = X_test.copy(), y_test.copy()
    print("Length train:",len(X_forest))
    print("Length test:",len(X_test_forest))
    ForestModel(X_forest, X_test_forest, y_forest, y_test_forest)
    print(f"The forest grew in: {round(time.time() - forest_time, 2)} seconds")
    print("\n")

    memory_usage = psutil.Process().memory_info().rss / 1024 **2

    # Show CPU + Memory
    print(f"Memory useage: {round(memory_usage)} MB")
    print(f"CPU percentage: {cpu_process.cpu_percent()} %")
    print(f"Run time of algorithm: {round(time.time() - start_time, 2)} seconds")
    



    print(len(data))

# %%
#UPDATE
# %run preprocessing.ipynb
# %run RandomForest.ipynb

# %%
run_all()
# Out:
# Loading data..
# Fetching the data took: 3.79 seconds
#
#
# Preprocessing initiated..
# Preprocessing took: 17.25 seconds
#
#
# Naive Baseline Initiated..
# Calculating time differences!
#
#
# Error metrics for the Naive Time time model
#
#
# Mean Absolute Error: 6825.508592723689
# Mean Squared Error: 425813621.8758078
# Root Mean Squared Error: 20635.251921791696
# $R_2$ score: -0.12167788810271696
#
#
# Time calculation done in: 1.01 seconds
# Predicting next events..
#
#
# Error metrics for the Naive Event event model
#
#
# The accuracy of the model is 0.3806625317005291.
# The precision of the model is 0.32842011174088465, using weighted average.
# The recall of the model is 0.3806625317005291, using weighted average.
# The f1-score of the model is 0.3425175516236353, using weighted average.
#
#
# Event prediction done in: 6.7 seconds
#
#
# The baseline model ran in 7.72 seconds
#
#
# features split
# Initial Linear Model Running!
#
#
# ...

# %% [markdown]
# 0.8757 full data without sorting TRAIN: 841k TEST: 360k
#
# 0.8748/0.8738/0.874 sampler pct=0.75 without sorting TRAIN: 631k TEST: 360k
#
# 0.8780 sampler pct=0.5 without sorting TRAIN: 420k TEST: 360k
#
# 0.8676 sampler pct=0.25 without sorting TRAIN: TEST:

# %%
8757

# %%
# data = get_data(TRAIN, TEST)

# processed = preprocess(data)

# %%
# X_train, X_test, y_train, y_test = features_split(processed)

# %% [raw]
# # y_train
